# %%
from IPython.display import display, HTML
import random


class FederPy:
    def __init__(self, indexFile, indexSource, mediaUrls=[], **viewParams):
        self.indexFile = indexFile
        self.indexSource = indexSource

        self.container = "feder-container-%s" % random.randint(0, 10000000)

        self.federjs = "https://unpkg.com/@zilliz/feder"
        # self.federjs = "http://192.168.0.101:12357/feder_esm.js"

        self.actionJs = ""
        self.searchParams = {}
        self.mediaUrls = mediaUrls
        self.viewParams = viewParams

    def getDiv(self):
        return '<div id="%s" />' % self.container

    def getInitJs(self):
        return """
import { Feder } from "%s"
// console.log(Feder)

const mediaUrls = [%s]
const mediaCallback = (rowId) => rowId in mediaUrls ? mediaUrls[rowId] : null

const feder = new Feder({
    filePath: "%s",
    source: "%s",
    domSelector: "#%s",
    viewParams: {
        ...%s,
        mediaCallback,
    }
})
        """ % (self.federjs, ",".join(["'%s'" % url for url in self.mediaUrls]), self.indexFile, self.indexSource, self.container, self.viewParams)

    def overview(self, isDisplay=True):
        self.actionJs = "feder.overview()"
        if isDisplay:
            self.showHtml()
        else:
            return self.getHtml()

    def searchById(self, targetId, isDisplay=True):
        self.actionJs = "feder.setSearchParams(%s)\nfeder.searchById(%s)" % (
            self.searchParams, targetId)
        if isDisplay:
            self.showHtml()
        else:
            return self.getHtml()

    def searchRandTestVec(self, isDisplay=True):
        self.actionJs = "feder.setSearchParams(%s)\nfeder.searchRandTestVec()" % self.searchParams
        if isDisplay:
            self.showHtml()
        else:
            return self.getHtml()

    def setSearchParams(self, searchParams):
        self.searchParams = searchParams

    def getJs(self):
        return """
# %s
# %s
        """ % (self.getInitJs(), self.actionJs)

    def getHtml(self):
        return """
<!DOCTYPE html>
<html>

<head>
  <meta charset="utf-8" />
  <meta name="viewport" content="width=device-width,initial-scale=1" />
  <meta name="theme-color" content="#ffffff" />
  <title>Feder</title>
</head>

<body style="background: #000">
  # %s
</body>

<script type="module">
# %s
</script>

</html> 
""" % (self.getDiv(), self.getJs())

    def showHtml(self):
        display(HTML(self.getHtml()))

# %%
# IVFFlat - Search
import csv
import pandas as pd
# this csv includes 17,000+ items，each of which includes its filename.
namesFile = "https://assets.zilliz.com/voc_names_4cee9440b1.csv"
namesCsv = pd.read_csv(namesFile)
names = [row['name'] for index, row in namesCsv.iterrows()]
imageUrls = ["https://assets.zilliz.com/voc2012/JPEGImages/%s" % name for name in names]

# %%
indexFile = 'https://assets.zilliz.com/faiss_ivf_flat_voc_17k_ab112eec72.index'
indexSource = 'faiss'

viewParams = {
    "width": 800,
    "height": 500,
    "mediaType": "img",
    "mediaUrls": imageUrls,
    "fineSearchWithProjection": 0,
    "projectMethod": "umap"
}
federPy = FederPy(indexFile, indexSource, **viewParams)
federPy.setSearchParams({"k": 15, "nprobe": 8})
federPy.searchById(1156)
# Out:
# <!DOCTYPE html>
# <html>
#
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width,initial-scale=1" />
#   <meta name="theme-color" content="#ffffff" />
#   <title>Feder</title>
# </head>
#
# <body style="background: #000">
#   <div id="feder-container-3950061" />
# </body>
#
# <script type="module">
#
#
# import { Feder } from "https://unpkg.com/@zilliz/feder"
# // console.log(Feder)
#
# const mediaUrls = ['https://assets.zilliz.com/voc2012/JPEGImages/2007_000027.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000032.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000033.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000039.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000042.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000061.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000063.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000068.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000121.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000123.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000129.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000170.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000175.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000187.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000241.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000243.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000250.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000256.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000272.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000323.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000332.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000333.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000346.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000363.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000364.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000392.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000423.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000452.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000464.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000480.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000491.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000504.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000515.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000528.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000529.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000549.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000559.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000572.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000584.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000629.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000636.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000645.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000648.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000661.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000663.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000664.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000676.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000713.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000720.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000727.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000733.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000738.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000762.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000768.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000783.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000793.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000799.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000804.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000807.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000822.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000830.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000836.jpg','https://assets.zilliz.com/voc2012/JPEGImages/2007_000837.jpg','https://ass ...
